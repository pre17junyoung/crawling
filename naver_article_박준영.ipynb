# %% [markdown]
# ## Selenium을 활용한 네이버 기사 크롤링

# %%
from selenium import webdriver
import time

# %%
driver = webdriver.Chrome()

url = "https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=1"
driver.get(url)

# %%
titles = []
for i in range(10):
    
    datas = driver.find_elements_by_css_selector('#section_body li > dl > dt:nth-child(2) > a')

    for title in datas:
        titles.append(title.text)
        
    driver.find_elements_by_css_selector('#paging a')[i].click()
    time.sleep(1)

df = pd.DataFrame(columns=['title'], data=titles)

# %%
df
# Out:
#                                                  title
# 0           < ICT & Science >애플도 접었다… 삼성發 ‘폴더블폰 전쟁’ 확전
# 1            < ICT & Science >접거나… 붙이거나… MWC ‘미래폰 3파전’
# 2                     '셧다운제 담당과장' 문체부 5번 바뀔 동안 여가부는 0번
# 3                          CJ헬로 매각, 결국 케이블 업계 퇴출로 이어지나
# 4                          화웨이 회장 “미국은 우리를 무너뜨리지 못할 것”
# 5    [넷마블서 손떼는 CJ] CJ ENM, 글로벌 M&Aㆍ콘텐츠 사업 강화ㆍ‘3세 경영...
# 6                SKT, 현대글로비스, 두나무 ‘대국민 블록체인 프로젝트’ 선보인다
# 7                 LG이노텍, 세계에서 가장 얇은 '스마트폰 3D 센싱 모듈' 양산
# 8                    비탈릭 부테린 vs 누리엘 루비니, 한국서 암호화폐를 논한다
# 9                        달아오르는 모바일 MMORPG 시장…신작 공세 뜨겁다
# 10                    삼성전자, 美서 요리로봇·청소로봇 등 '미래AI 홈' 선봬
# 11                   SK텔레콤, 키움증권 주도 제3인터넷은행 참여..10% 미만
# 12           [팩트체크] "IE 탈출" 경고 귀닫은 한국…OECD 2위 '보안 불감증'
# 13                       네이버 노조 첫 쟁의는 파업 아닌 '점심 로비 시위'
# 14                    [MWC]SKT, 넥슨과 손잡고 '카트라이더VR' 내놓는다
# 15                          SKT-KT, 5G 킬러콘텐츠로 ‘게임’ 택했다
# ...

# %%
driver.quit()
